# %% [markdown]
# <a href="https://colab.research.google.com/github/whiteevl/machine-learning/blob/main/Creating_and_Training_Models_to_Process_Image_Datasets_from_the_Real_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
    https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2023-12-09 08:45:34--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2023-12-09 08:45:34--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   188MB/s    in 0.3s
#
# 2023-12-09 08:45:35 (188 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Knight', 'Bishop', 'Pawn', 'Queen', 'Rook', 'King']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 44s - loss: 1.8315 - accuracy: 0.1703 - val_loss: 1.7875 - val_accuracy: 0.2115 - 44s/epoch - 695ms/step
# Epoch 2/50
# 63/63 - 42s - loss: 1.7802 - accuracy: 0.2084 - val_loss: 1.7776 - val_accuracy: 0.2115 - 42s/epoch - 666ms/step
# Epoch 3/50
# 63/63 - 42s - loss: 1.7716 - accuracy: 0.2224 - val_loss: 1.7326 - val_accuracy: 0.2115 - 42s/epoch - 662ms/step
# Epoch 4/50
# 63/63 - 43s - loss: 1.7425 - accuracy: 0.2625 - val_loss: 1.7406 - val_accuracy: 0.2692 - 43s/epoch - 679ms/step
# Epoch 5/50
# 63/63 - 45s - loss: 1.6720 - accuracy: 0.3086 - val_loss: 1.6573 - val_accuracy: 0.2885 - 45s/epoch - 712ms/step
# Epoch 6/50
# 63/63 - 42s - loss: 1.7067 - accuracy: 0.2705 - val_loss: 1.6706 - val_accuracy: 0.2692 - 42s/epoch - 673ms/step
# Epoch 7/50
# 63/63 - 41s - loss: 1.6080 - accuracy: 0.3487 - val_loss: 1.7169 - val_accuracy: 0.3462 - 41s/epoch - 653ms/step
# Epoch 8/50
# 63/63 - 40s - loss: 1.5850 - accuracy: 0.3487 - val_loss: 1.6163 - val_accuracy: 0.3462 - 40s/epoch - 636ms/step
# Epoch 9/50
# 63/63 - 42s - loss: 1.5281 - accuracy: 0.3808 - val_loss: 1.5844 - val_accuracy: 0.3654 - 42s/epoch - 665ms/step
# Epoch 10/50
# 63/63 - 40s - loss: 1.4412 - accuracy: 0.4429 - val_loss: 1.4972 - val_accuracy: 0.4615 - 40s/epoch - 639ms/step
# Epoch 11/50
# 63/63 - 40s - loss: 1.4918 - accuracy: 0.4048 - val_loss: 1.6061 - val_accuracy: 0.2885 - 40s/epoch - 635ms/step
# Epoch 12/50
# 63/63 - 40s - loss: 1.3888 - accuracy: 0.4409 - val_loss: 1.5338 - val_accuracy: 0.3846 - 40s/epoch - 637ms/step
# Epoch 13/50
# 63/63 - 41s - loss: 1.3700 - accuracy: 0.4609 - val_loss: 1.6256 - val_accuracy: 0.2500 - 41s/epoch - 657ms/step
# Epoch 14/50
# 63/63 - 44s - loss: 1.2635 - accuracy: 0.5110 - val_loss: 1.5325 - val_accuracy: 0.4615 - 44s/epoch - 700ms/step
# Epoch 15/50
# 63/63 - 42s - loss: 1.2623 - accuracy: 0.4910 - val_loss: 1.4820 - val_accuracy: 0.4615 - 42s/epoch - 663ms/step
# Epoch 16/50
# 63/63 - 41s - loss: 1.2493 - accuracy: 0.5150 - val_loss: 1.4945 - val_accuracy: 0.3846 - 41s/epoch - 656ms/step
# Epoch 17/50
# 63/63 - 41s - loss: 1.1455 - accuracy: 0.5531 - val_loss: 1.5835 - val_accuracy: 0.4231 - 41s/epoch - 658ms/step
# Epoch 18/50
# 63/63 - 43s - loss: 1.1009 - accuracy: 0.5531 - val_loss: 1.5022 - val_accuracy: 0.3077 - 43s/epoch - 676ms/step
# Epoch 19/50
# 63/63 - 41s - loss: 1.0768 - accuracy: 0.6092 - val_loss: 1.4479 - val_accuracy: 0.4038 - 41s/epoch - 644ms/step
# Epoch 20/50
# 63/63 - 41s - loss: 1.0544 - accuracy: 0.6212 - val_loss: 1.4127 - val_accuracy: 0.4231 - 41s/epoch - 657ms/step
# Epoch 21/50
# 63/63 - 42s - loss: 1.0718 - accuracy: 0.5992 - val_loss: 1.4135 - val_accuracy: 0.4808 - 42s/epoch - 671ms/step
# Epoch 22/50
# 63/63 - 45s - loss: 0.9787 - accuracy: 0.6293 - val_loss: 1.6233 - val_accuracy: 0.4615 - 45s/epoch - 710ms/step
# Epoch 23/50
# 63/63 - 42s - loss: 0.9271 - accuracy: 0.6433 - val_loss: 1.4831 - val_accuracy: 0.4808 - 42s/epoch - 661ms/step
# Epoch 24/50
# 63/63 - 42s - loss: 0.9952 - accuracy: 0.6232 - val_loss: 1.4029 - val_accuracy: 0.5000 - 42s/epoch - 661ms/step
# Epoch 25/50
# 63/63 - 40s - loss: 0.9128 - accuracy: 0.6613 - val_loss: 1.6392 - val_accuracy: 0.4038 - 40s/epoch - 640ms/step
# Epoch 26/50
# 63/63 - 41s - loss: 0.8111 - accuracy: 0.7114 - val_loss: 1.3924 - val_accuracy: 0.4615 - 41s/epoch - 652ms/step
# Epoch 27/50
# 63/63 - 40s - loss: 0.8967 - accuracy: 0.6774 - val_loss: 1.2528 - val_accuracy: 0.5192 - 40s/epoch - 640ms/step
# Epoch 28/50
# 63/63 - 42s - loss: 0.7464 - accuracy: 0.7395 - val_loss: 1.4324 - val_accuracy: 0.4808 - 42s/epoch - 669ms/step
# Epoch 29/50
# 63/63 - 42s - loss: 0.8191 - accuracy: 0.7194 - val_loss: 1.3062 - val_accuracy: 0.5000 - 42s/epoch - 663ms/step
# Epoch 30/50
# 63/63 - 42s - loss: 0.7768 - accuracy: 0.7295 - val_loss: 1.2222 - val_accuracy: 0.6346 - 42s/epoch - 661ms/step
# Epoch 31/50
# 63/63 - 41s - loss: 0.7325 - accuracy: 0.7375 - val_loss: 1.4735 - val_accuracy: 0.4615 - 41s/epoch - 648ms/step
# Epoch 32/50
# 63/63 - 40s - loss: 0.7430 - accuracy: 0.7315 - val_loss: 1.5735 - val_accuracy: 0.4038 - 40s/epoch - 634ms/step
# Epoch 33/50
# 63/63 - 41s - loss: 0.6591 - accuracy: 0.7395 - val_loss: 1.4983 - val_accuracy: 0.4423 - 41s/epoch - 648ms/step
# Epoch 34/50
# 63/63 - 42s - loss: 0.6261 - accuracy: 0.7956 - val_loss: 1.6851 - val_accuracy: 0.4615 - 42s/epoch - 667ms/step
# Epoch 35/50
# 63/63 - 42s - loss: 0.6048 - accuracy: 0.7856 - val_loss: 1.5004 - val_accuracy: 0.5385 - 42s/epoch - 663ms/step
# Epoch 36/50
# 63/63 - 42s - loss: 0.6364 - accuracy: 0.7615 - val_loss: 1.3050 - val_accuracy: 0.4615 - 42s/epoch - 667ms/step
# Epoch 37/50
# 63/63 - 40s - loss: 0.5977 - accuracy: 0.7856 - val_loss: 1.5496 - val_accuracy: 0.3462 - 40s/epoch - 641ms/step
# Epoch 38/50
# 63/63 - 40s - loss: 0.5100 - accuracy: 0.8136 - val_loss: 1.5726 - val_accuracy: 0.4808 - 40s/epoch - 633ms/step
# Epoch 39/50
# 63/63 - 42s - loss: 0.5086 - accuracy: 0.8056 - val_loss: 1.4983 - val_accuracy: 0.4423 - 42s/epoch - 664ms/step
# Epoch 40/50
# 63/63 - 42s - loss: 0.5906 - accuracy: 0.7916 - val_loss: 1.4678 - val_accuracy: 0.5385 - 42s/epoch - 666ms/step
# Epoch 41/50
# 63/63 - 44s - loss: 0.4534 - accuracy: 0.8337 - val_loss: 1.4252 - val_accuracy: 0.4615 - 44s/epoch - 697ms/step
# Epoch 42/50
# 63/63 - 40s - loss: 0.4890 - accuracy: 0.8257 - val_loss: 1.5579 - val_accuracy: 0.5192 - 40s/epoch - 639ms/step
# Epoch 43/50
# 63/63 - 39s - loss: 0.5295 - accuracy: 0.8277 - val_loss: 1.6722 - val_accuracy: 0.4038 - 39s/epoch - 625ms/step
# Epoch 44/50
# 63/63 - 42s - loss: 0.4298 - accuracy: 0.8537 - val_loss: 1.4885 - val_accuracy: 0.4808 - 42s/epoch - 668ms/step
# Epoch 45/50
# 63/63 - 42s - loss: 0.4778 - accuracy: 0.8216 - val_loss: 1.5099 - val_accuracy: 0.3654 - 42s/epoch - 664ms/step
# Epoch 46/50
# 63/63 - 43s - loss: 0.4129 - accuracy: 0.8417 - val_loss: 1.9004 - val_accuracy: 0.3846 - 43s/epoch - 677ms/step
# Epoch 47/50
# 63/63 - 40s - loss: 0.4804 - accuracy: 0.8377 - val_loss: 1.6215 - val_accuracy: 0.5385 - 40s/epoch - 637ms/step
# Epoch 48/50
# 63/63 - 39s - loss: 0.4372 - accuracy: 0.8437 - val_loss: 1.4521 - val_accuracy: 0.4808 - 39s/epoch - 616ms/step
# Epoch 49/50
# 63/63 - 42s - loss: 0.3324 - accuracy: 0.8858 - val_loss: 1.9027 - val_accuracy: 0.3462 - 42s/epoch - 660ms/step
# Epoch 50/50
# 63/63 - 44s - loss: 0.4170 - accuracy: 0.8497 - val_loss: 1.5431 - val_accuracy: 0.5192 - 44s/epoch - 695ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
